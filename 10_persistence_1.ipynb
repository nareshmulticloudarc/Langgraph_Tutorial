# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
import os
print(os.getenv('OPENAI_API_KEY'))
# Out:
# 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

# %%
load_dotenv()
llm = ChatOpenAI()

# %%
class JokeState(TypedDict):
    topic: str
    joke: str
    explanation: str

# %%
def generate_joke_func(state: JokeState):
    prompt=f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content
    return {'joke': response}

def generate_explanation_func(state: JokeState):
    prompt=f'write an explanation for the joke - {state["topic"]}'
    response = llm.invoke(prompt).content
    return {'explanation':response}

# %%
graph= StateGraph(JokeState)

graph.add_node('generate_joke',generate_joke_func)
graph.add_node('generate_explanation',generate_explanation_func)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke','generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable":{"thread_id":"2"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the pasta go to the party? Because it heard it was going to be a penne-pasta event!',
#  'explanation': 'The joke is a play on words, as "pasta" sounds similar to the word "pastor." In this context, the punchline of the joke is implying that instead of asking a pastor for guidance or advice in a difficult situation, the person went to a plate of pasta instead, highlighting the silliness and absurdity of the decision. It\'s a lighthearted and silly joke that plays on the similarity in sounds between the two words.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the slice of pizza go to the party? \nBecause it wanted to be a supreme guest!', 'explanation': 'The joke about pizza likely revolves around the popular and universally loved food, prompting a humorous response or pun related to pizza toppings, delivery services, or different ways to eat it. Pizza jokes are often light-hearted and funny, as pizza is a beloved food that many people enjoy.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b4d8f-4f00-6ef4-800e-908f2278167f'}}, metadata={'source': 'loop', 'step': 14, 'parents': {}}, created_at='2025-10-29T15:07:16.378391+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b4d8f-3d88-68ac-800d-18108e8bd747'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the slice of pizza go to the party? \nBecause it wanted to be a supreme guest!', 'explanation': 'The joke about pizza likely revolves around the popular and universally loved food, prompting a humorous response or pun related to pizza toppings, delivery services, or different ways to eat it. Pizza jokes are often light-hearted and funny, as pizza is a beloved food that many people enjoy.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b4d8f-4f00-6ef4-800e-908f2278167f'}}, metadata={'source': 'loop', 'step': 14, 'parents': {}}, created_at='2025-10-29T15:07:16.378391+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b4d8f-3d88-68ac-800d-18108e8bd747'}}, tasks=(), interrupts=()),
# ...

# %%
config2 = {"configurable":{"thread_id":"2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti break up with the linguine? \n\nBecause it was tired of all the pasta-tivity in the relationship!',
#  'explanation': 'The joke most likely involves a play on words or a pun related to pasta, which is a type of food made from dough that is typically boiled and served with sauce. Pasta can sound similar to the word "passed her," so the joke could involve a scenario where someone passes a plate of pasta to a woman named "her," resulting in a humorous or unexpected outcome. The humor likely comes from the unexpected twist in the word play or the absurdity of the situation.'}

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti break up with the linguine? \n\nBecause it was tired of all the pasta-tivity in the relationship!', 'explanation': 'The joke most likely involves a play on words or a pun related to pasta, which is a type of food made from dough that is typically boiled and served with sauce. Pasta can sound similar to the word "passed her," so the joke could involve a scenario where someone passes a plate of pasta to a woman named "her," resulting in a humorous or unexpected outcome. The humor likely comes from the unexpected twist in the word play or the absurdity of the situation.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0b4d98-369d-67dc-800a-325b9a966868'}}, metadata={'source': 'loop', 'step': 10, 'parents': {}}, created_at='2025-10-29T15:11:15.414012+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0b4d98-2f34-6075-8009-b7
# ...

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti break up with the linguine? \n\nBecause it was tired of all the pasta-tivity in the relationship!', 'explanation': 'The joke most likely involves a play on words or a pun related to pasta, which is a type of food made from dough that is typically boiled and served with sauce. Pasta can sound similar to the word "passed her," so the joke could involve a scenario where someone passes a plate of pasta to a woman named "her," resulting in a humorous or unexpected outcome. The humor likely comes from the unexpected twist in the word play or the absurdity of the situation.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0b4d98-369d-67dc-800a-325b9a966868'}}, metadata={'source': 'loop', 'step': 10, 'parents': {}}, created_at='2025-10-29T15:11:15.414012+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0b4d98-2f34-6075-8009-b
# ...
